# %% [markdown]
# # Прежде всего сформилируем условия задачи:
# Выбрать базу по генотипированию в базе открытого доступа по ссылке
# https://www.opensnp.org/genotypes
# Внести информацию о выбранном генотипе в гугл-док таблицу –
# https://docs.google.com/spreadsheets/d/1SV4fj1_nTo4kw9_9-r5rfWuyPKBWQUB09BsTEN0581k/edit?usp=sharing
#
# Провести исследование и ответить
#  1. Какой наиболее вероятный цвет глаз у этого человека?
# с помощью системы IrisPlex (https://hirisplex.erasmusmc.nl)
#  2. Повышен или понижен риск тромбоза у данного человека? (по желанию, на 10 баллов)
#   - на основе модели из 5 SNPs – rs6025 (F5, factor V Leiden), rs1799963 (F2, 20210 G > A), rs8176719 (ABO), rs2066865 (FGG, 10034 C > T), and rs2036914 (F11) (как на семинаре) (ответ на этот вопрос, при условии ответов на предыдущие дает 10)
#
#  3-5 . Из snpedia выбрать три разных интересных снипа и проверить на предрасположенность/связи с тем или иным признаком (см например, список popular или любой другой)
#
# Представить развернутые отчеты. В отчете должна присутствовать информация о том, какие генотипы рисковые (cкриншот из snipedia или другого ресурса), какой генотип у вашего человека, и какой вывод вы сделали.

# %% [markdown]
# # Прежде всего выпишем выбранного человека:
# https://opensnp.org/users/11717

# %% [markdown]
# # Пункт 1:
# Для определения наиболее вероятного цвета глаз мы можем воспользоваться системой IrisPlex, которая анализирует генотип нескольких маркеров и предсказывает вероятный цвет глаз.
#
# Чтобы использовать систему IrisPlex, нам нужно ввести генотип пользователя в соответствующее поле на сайте https://hirisplex.erasmusmc.nl. Воспользуемся файлом с генотипом пользователя 11703, который мы загрузили (предварительно поместив его номер в таблицу), и скопируем последовательность в поле "Input genotypes".
#
# **После нажатия на кнопку "Calculate", начинается процесс анализа последовательности:**
#
# ![image.png](data:image/png;base64,...)
#
# В результате мы получим таблицу, из которой узнаем результат:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Но в самом же деле было быстрее найти нужные SNP и внести в таблицу:**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **По итогу мы делаем вывод, что у человека, скорее всего, коричневый цвет глаз.**

# %% [markdown]
# # Пункт 2:
# Далее узнаем вероятность тромбоза, рассмотрев rs6025 (F5, factor V Leiden), rs1799963 (F2, 20210 G > A), rs8176719 (ABO), rs2066865 (FGG, 10034 C > T), rs2036914 (F11)
#
# Для этого найдем нужные гены в генотипе (rs8176719 отсутсвует)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Проанализировав статью [Multiple SNP testing improves risk prediction of first venous thrombosis](https://ashpublications.org/blood/article/120/3/656/30474/Multiple-SNP-testing-improves-risk-prediction-of), можно выяснить, что рискованными являются **rs6025 - AA, rs1799963 - AA, rs8176719 - GG, rs2066865 - TT, rs2036914 - CC**, делаем вывод о том, что рискованного генотипа нет.

# %% [markdown]
# # Пункт 3:
#
# Теперь выберем 3 снипа и проверим на предрасположенность нашего человека к данному заболеванию:

# %% [markdown]
# 1. **rs1800497 (MTHFR gene):** данный ген кодирует фермент, участвующий в метаболизме фолиевой кислоты. Некоторые варианты этого гена могут быть связаны с повышенным риском различных заболеваний, таких как сердечно-сосудистые заболевания и диабет.
#
# Посмотрим, что находится в данном гене у нашего человека:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# После того, как мы узнали, что это "GG" посмотрим, что на этот результат скажет SNPedia:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# (G;G)~(C;C). Таким образом, у нашего товарища все гуд. Риск диабета и заболеваний сердечной системы из-за даного генома не повышен.

# %% [markdown]
# 2. **rs53576 (Oxytocin receptor gene):** данный ген кодирует рецептор окситоцина, который играет важную роль в социальном поведении и психическом здоровье. Согласно некоторым исследованиям, некоторые варианты этого гена могут связываться с уровнем социальной тревожности и степенью эмоциональной связанности с другими людьми.
#
# Снова рассмотрим то, что в данном геноме выбранного нами файла:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Что же в SNPedia?
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Получается, что наш индвид недостаточно эмпатичен по отношению к окружающему миру, что весьма грустно(

# %% [markdown]
# 3. **rs4680 (COMT gene):** данный ген кодирует фермент, участвующий в метаболизме нейромедиаторов, включая дофамин. Некоторые варианты этого гена могут быть связаны с различными психическими характеристиками, такими как когнитивные функции и уровень тревожности.

# %% [markdown]
# Из генома мы видим:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Снова проанализируем результат через SNPedia:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Результат говорит о среднем уровне допамина, что говорит нам о других эффектах, в частности видим следующее:
#
# ![image.png](data:image/png;base64,...)
